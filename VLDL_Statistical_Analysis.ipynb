# %%
# !git clone https://github.com/mattaralaa/VLDL-Statistical-Analysis.git
# %cd VLDL-Statistical-Analysis
# !python analysis.py
# Out:
# Cloning into 'VLDL-Statistical-Analysis'...
# remote: Enumerating objects: 14, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 14 (delta 2), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (14/14), 16.25 KiB | 2.32 MiB/s, done.
# Resolving deltas: 100% (2/2), done.
# /content/VLDL-Statistical-Analysis
# Libraries loaded successfully.
# ...
# File loaded successfully: DiabetesIII1.csv
# ...
# Dataset shape: (1000, 12)
#
# First 5 rows:
#    Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL   BMI  CLASS
# 0       0   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5  24.0      2
# 1       1   26   4.5  62    4.9   3.7  1.4  1.1  2.1   0.6  23.0      2
# 2       0   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5  24.0      2
# 3       0   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5  24.0      2
# 4       1   33   7.1  46    4.9   4.9  1.0  0.8  2.0   0.4  21.0      2
#
# Columns:
# ...
